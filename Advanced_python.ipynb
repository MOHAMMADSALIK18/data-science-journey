# %% [markdown]
# ```
# Decorator
# B A decorator is just a function that modifies another function
# without changing its actual code.F
# B Imagine you have a cake (your function). A decorator is like
# putting icing on the cake. It doesn’t change the cake itself, but
# makes it better, prettier, or adds some new flavorI
# B For creating a decorator you first have to create a decorator
# functions and then inside that we will create a wrapper.F
# B Its tough to understand with text see the video3
