# %% [markdown]
# <a href="https://colab.research.google.com/github/MOHAMMADSALIK18/data-science-journey/blob/main/OOPS%20concept.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Factory:
  def __init__(self,materials,zips,pockets):
    self.materials=materials
    self.zips=zips
    self.pockets=pockets
    print(self)

  def show(self):
    print(f"Your requirements are:- {self.materials}.{self.zips},{self.pockets}")

reebock=Factory("Leathers",3,2)

campus=Factory("Nylon",4,3)

print(reebock.materials)
print(campus.zips)

reebock.show()
campus.show()

@classmethod
def hekko(cls):
  print("How are you.")

@staticmethod
def static():
  print("How are you brother.")

obj=Factory("Linen",1,4)
obj.show()
# Out:
# <__main__.Factory object at 0x7d288b8f5bb0>
# <__main__.Factory object at 0x7d288baf2a50>
# Leathers
# 4
# Your requirements are:- Leathers.3,2
# Your requirements are:- Nylon.4,3
# <__main__.Factory object at 0x7d2898314320>
# Your requirements are:- Linen.1,4

# %%
class Factorymumbai:
  a="I am an attribute mentioned inside Factory"
  def hello(self):
    print("hello i am a mentioned inside Factory.")

class Factorypune(Factorymumbai):
  pass

obj=Factorymumbai()

obj2=Factorypune()

print(obj2.hello())
# Out:
# hello i am a mentioned inside Factory.
# None

# %%
class Animal:
  def __init__(self,name):
    self.name = name

    def show():
      print(f"Hello your name is:- {self.name}")

class Human(Animal):
  def __init__(self, name,age):
    super().__init__(name)
    self.age=age

  def show(self):
      print(f"Hello your name is:- {self.name},{self.age}")

animal1=Animal("Wolf")
person1=Human("Salik",23)

print(animal1.name)
print(person1.name,person1.age)
# Out:
# Wolf
# Salik 23

# %%
class Factory:
  def __init__(self,material,zips):
    self.material=material
    self.zips=zips

class Bhopalfactory(Factory):
  def __init__(self, material, zips,color):
    super().__init__(material, zips)
    self.color=color

class Punefactory(Bhopalfactory):
  def __init__(self, material, zips, color,pockets):
    super().__init__(material, zips, color)
    self.pockets=pockets

obj=Punefactory("Leather",4,"Black",5)

print(obj.material,obj.zips,obj.pockets,obj.color)
# Out:
# Leather 4 5 Black
